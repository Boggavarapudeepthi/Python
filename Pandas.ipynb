# %% [markdown]
# <a href="https://colab.research.google.com/github/Boggavarapudeepthi/Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    "NAME":["SAI","PANDU","SATHISH","SATYA","PRASAD","CHINNU"],
    "AGE":[23,25,30,40,32,13],
    "CITY":["ONGOLE", "DARSI", "VIJAYAVADA","ADDANKI","PODILI","PURIMETLA"],
}
df=pd.DataFrame(data)
print(df)
# Out:
#       NAME  AGE        CITY
# 0      SAI   23      ONGOLE
# 1    PANDU   25       DARSI
# 2  SATHISH   30  VIJAYAVADA
# 3    SATYA   40     ADDANKI
# 4   PRASAD   32      PODILI
# 5   CHINNU   13   PURIMETLA

# %%
[df.head]
# Out:
# [<bound method NDFrame.head of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
[df.tail]
# Out:
# [<bound method NDFrame.tail of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
[df.info]
# Out:
# [<bound method DataFrame.info of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
[df.NAME]
# Out:
# [0        SAI
#  1      PANDU
#  2    SATHISH
#  3      SATYA
#  4     PRASAD
#  5     CHINNU
#  Name: NAME, dtype: object]

# %%
[df.shape]
# Out:
# [(6, 3)]

# %%
[df.describe]
# Out:
# [<bound method NDFrame.describe of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
(df[df["AGE"]>20])
# Out:
#       NAME  AGE        CITY
# 0      SAI   23      ONGOLE
# 1    PANDU   25       DARSI
# 2  SATHISH   30  VIJAYAVADA
# 3    SATYA   40     ADDANKI
# 4   PRASAD   32      PODILI

# %%
[df.columns]
# Out:
# [Index(['NAME', 'AGE', 'CITY'], dtype='object')]

# %%
[df.index]
# Out:
# [RangeIndex(start=0, stop=6, step=1)]

# %%
[df.loc[0]]
# Out:
# [NAME       SAI
#  AGE         23
#  CITY    ONGOLE
#  Name: 0, dtype: object]

# %%
[df.iloc[0:4]]
# Out:
# [      NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI]

# %%
[df.isnull()]
# Out:
# [    NAME    AGE   CITY
#  0  False  False  False
#  1  False  False  False
#  2  False  False  False
#  3  False  False  False
#  4  False  False  False
#  5  False  False  False]

# %%
[df.duplicated]
# Out:
# [<bound method DataFrame.duplicated of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
[df.drop_duplicates]
# Out:
# [<bound method DataFrame.drop_duplicates of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]

# %%
[df.fillna]
# Out:
# [<bound method NDFrame.fillna of       NAME  AGE        CITY
#  0      SAI   23      ONGOLE
#  1    PANDU   25       DARSI
#  2  SATHISH   30  VIJAYAVADA
#  3    SATYA   40     ADDANKI
#  4   PRASAD   32      PODILI
#  5   CHINNU   13   PURIMETLA>]
