# %% [markdown]
# <a href="https://colab.research.google.com/github/Boggavarapudeepthi/Python/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2

# %%
import numpy as np
a=np.array([10,20,30])
print(a)
# Out:
# [10 20 30]

# %%
#tri dimentional array
import numpy as np
a=np.array([[10,20],[30,40],[50,60]])
print(a)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]]

# %%
a=np.array([[10,20],[30,40]])
print(a)
# Out:
# [[10 20]
#  [30 40]]

# %%
a=np.array([[10,20],[30,40]])
print(a[0][1])
# Out:
# 20

# %%
a=np.array([[[10,20],[30,40]],[[50,60],[70,80]]])
print(a)
# Out:
# [[[10 20]
#   [30 40]]
#
#  [[50 60]
#   [70 80]]]
